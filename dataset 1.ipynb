# %%
import pandas as pd

import geopy
import meteostat

# %%
df_disasters= pd.read_pickle(r"C:\Users\vitor\Documents\Data Science\Capstone\df_disaster3pck")

# %%
df_disasters
# Out:
#               Dis No  Year   Seq Disaster Subgroup Disaster Type  \
# 0      1960-0026-AIA  1960    26    Meteorological         Storm
# 1      1960-0025-ANT  1960    25    Meteorological         Storm
# 2      1960-0024-ATG  1960    24    Meteorological         Storm
# 3      1960-0030-BGD  1960    30    Meteorological         Storm
# 4      1960-0031-BGD  1960    31    Meteorological         Storm
# ...              ...   ...   ...               ...           ...
# 12518  2022-0788-ZAF  2022   788      Hydrological         Flood
# 12519  2022-0313-ZAF  2022   313      Hydrological         Flood
# 12520  2022-0356-ZAF  2022   356      Hydrological         Flood
# 12521  2022-9784-COD  2022  9784    Climatological       Drought
# 12522  2022-0650-SSD  2022   650      Hydrological         Flood
#
#        Disaster Subtype Disaster Subsubtype Event Name  \
# 0      Tropical cyclone                 NaN      Donna
# 1      Tropical cyclone                 NaN      Donna
# ...

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)

# Create Point for Vancouver, BC
vancouver = Point(49.2497, -123.1193, 70)

# Get daily data for 2018
data = Daily(vancouver, start, end)
data = data.fetch()

# %%
df_coord=pd.read_csv(r'C:\Users\vitor\Documents\Data Science\Capstone\df_cord.csv')
df_coord.head(1)
df_coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  221 non-null    object
#  1   latitude    221 non-null    float64
#  2   longitude   221 non-null    float64
#  3   Country     221 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 7.0+ KB

# %%
lista_lat=df_coord['latitude']
lista_long=df_coord['longitude']
lista_country=df_coord['Country']

# %%
from datetime import datetime
from meteostat import Point, Daily

d=pd.DataFrame()
start= datetime(1960,1,1)
end=datetime(2022,12,31)

for i,j,z in zip(lista_lat,lista_long,lista_country):
   point=Point(i,j)
   data=Daily(point,start,end)
   data=data.fetch()
   data['Country']= z
   d=pd.concat([d,data])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\vitor\Documents\Data Science\Capstone\dataset 1.ipynb Cell 7 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/vitor/Documents/Data%20Science/Capstone/dataset%201.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> end=datetime(2022,12,31)
#       <a href='vscode-notebook-cell:/c%3A/Users/vitor/Documents/Data%20Science/Capstone/dataset%201.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> for i,j,z in zip(lista_lat,lista_long,lista_country):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vitor/Documents/Data%20Science/Capstone/dataset%201.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>    point=Point.nearby(i,j)
#      <a href='vscode-notebook-cell:/c%3A/Users/vitor/Documents/Data%20Science/Capstone/dataset%201.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>    data=Daily(point,start,end)
# ...

# %%
from datetime import datetime
from meteostat import Point, Daily
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\vitor\Documents\Data Science\Capstone\dataset 1.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/vitor/Documents/Data%20Science/Capstone/dataset%201.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> from datetime import datetime
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vitor/Documents/Data%20Science/Capstone/dataset%201.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> from meteostat import Point, Daily, Radius
#
# ImportError: cannot import name 'Radius' from 'meteostat' (c:\Users\vitor\anaconda3\lib\site-packages\meteostat\__init__.py)

# %%
from datetime import datetime
from meteostat import Point, Daily

d=pd.DataFrame()
start= datetime(1960,1,1)
end=datetime(2022,12,31)

for i,j,z in zip(lista_lat,lista_long,lista_country):
   point=Point(i,j)
   data=Daily(point,start,end)
   data=data.fetch()
   data['Country']= z
   d=pd.concat([d,data])

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1699243 entries, 2005-01-01 to 2022-12-31
# Data columns (total 11 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   tavg     float64
#  1   tmin     float64
#  2   tmax     float64
#  3   prcp     float64
#  4   snow     float64
#  5   wdir     float64
#  6   wspd     float64
#  7   wpgt     float64
#  8   pres     float64
#  9   tsun     float64
#  10  Country  object
# dtypes: float64(10), object(1)
# memory usage: 155.6+ MB

# %%
d['Country'].unique()
# Out:
# array(['Anguilla', 'Netherlands Antilles', 'Antigua and Barbuda',
#        'Hong Kong', 'France', 'India', 'Germany', 'Guam', 'Belgium',
#        'Bahamas (the)', 'Dominican Republic (the)', 'Grenada', 'Ecuador',
#        'Guadeloupe', 'Switzerland', 'American Samoa',
#        'United Kingdom of Great Britain and Northern Ireland (the)',
#        'Congo (the)', 'Cook Islands (the)', 'Costa Rica', 'Cyprus',
#        'Guatemala', 'Barbados', 'Hungary', 'Czechoslovakia', 'Austria',
#        'Denmark', 'Japan', 'Saint Lucia', 'Martinique', 'Mauritius',
#        'Niue', 'Philippines (the)', 'Puerto Rico',
#        'United States of America (the)', 'Korea (the Republic of)',
#        'Soviet Union', 'Thailand', 'Trinidad and Tobago', 'Nepal',
#        'Pakistan', 'Niger (the)', 'Togo', 'Tokelau', 'Iraq',
#        'El Salvador', 'Romania', 'Papua New Guinea', 'Netherlands (the)',
#        'Tuvalu', 'Rwanda', 'Sudan (the)', 'Poland', 'Viet Nam', 'Samoa',
# ...

# %%
df_coord['Country'].unique()
# Out:
# array(['Anguilla', 'Netherlands Antilles', 'Antigua and Barbuda',
#        'Bangladesh', 'Hong Kong', 'Belize', 'Canada', 'France', 'Greece',
#        'Honduras', 'India', 'Colombia', 'Germany', 'Spain', 'Guam',
#        'Haiti', 'Afghanistan', 'Belgium', 'Bahamas (the)', 'Cuba',
#        'Dominica', 'Dominican Republic (the)', 'Algeria', 'Grenada',
#        'Brazil', 'China', 'Ecuador', 'Fiji', 'Guadeloupe', 'Argentina',
#        'Bulgaria', 'Bolivia (Plurinational State of)', 'Botswana',
#        'Switzerland', 'Chile', 'Ethiopia', 'Indonesia', 'American Samoa',
#        'Burkina Faso',
#        'United Kingdom of Great Britain and Northern Ireland (the)',
#        'Australia', 'Congo (the)', 'Cook Islands (the)', 'Ghana',
#        'Gambia (the)', 'Benin', 'Cabo Verde', 'Guinea-Bissau',
#        'Costa Rica', 'Cyprus', 'Guatemala', 'Barbados', 'Hungary',
#        'Cameroon', 'Guyana', 'Central African Republic', 'Czechoslovakia',
# ...

# %%
Point.radius=500000

# %%
point=Point
point=Point(61.0666922,-107.991707)
data_c=Daily(point,start,end)
data_c=data_c.fetch()

# %%
data_c
# Out:
#             tavg  tmin  tmax  prcp   snow   wdir  wspd  wpgt    pres  tsun
# time
# 1962-02-17   NaN -31.1 -15.6   0.0  380.0    NaN   NaN   NaN     NaN   NaN
# 1962-02-18   NaN -34.4 -18.9   0.0  380.0    NaN   NaN   NaN     NaN   NaN
# 1962-02-19   NaN -37.8 -24.4   0.0  380.0    NaN   NaN   NaN     NaN   NaN
# 1962-02-20   NaN -41.1 -25.0   0.0  380.0    NaN   NaN   NaN     NaN   NaN
# 1962-02-21   NaN -36.1 -17.8   0.0  380.0    NaN   NaN   NaN     NaN   NaN
# ...          ...   ...   ...   ...    ...    ...   ...   ...     ...   ...
# 2022-12-27 -12.4 -16.1  -8.7   0.8    NaN  112.0  26.7   NaN  1013.4   NaN
# 2022-12-28  -9.0 -11.4  -6.6   0.0    NaN  138.0  24.0   NaN  1011.7   NaN
# 2022-12-29 -12.7 -18.0  -7.4   0.0  500.0  150.0  17.2   NaN  1012.1   NaN
# 2022-12-30 -12.7 -18.4  -6.9   0.0    NaN  154.0  13.6   NaN  1007.1   NaN
# 2022-12-31  -8.8 -14.7  -2.9   0.0    NaN  190.0   5.5   NaN  1006.9   NaN
#
# [22233 rows x 10 columns]
