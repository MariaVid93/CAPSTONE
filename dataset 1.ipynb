# %%
import pandas as pd
import numpy as np
import geopy
import meteostat

# %%
df_disasters= pd.read_pickle(r"C:\Users\vitor\Documents\Data Science\Capstone\df_disaster3pck")

# %%
df_disasters
# Out:
#               Dis No  Year   Seq Disaster Subgroup Disaster Type  \
# 0      1960-0026-AIA  1960    26    Meteorological         Storm
# 1      1960-0025-ANT  1960    25    Meteorological         Storm
# 2      1960-0024-ATG  1960    24    Meteorological         Storm
# 3      1960-0030-BGD  1960    30    Meteorological         Storm
# 4      1960-0031-BGD  1960    31    Meteorological         Storm
# ...              ...   ...   ...               ...           ...
# 12518  2022-0788-ZAF  2022   788      Hydrological         Flood
# 12519  2022-0313-ZAF  2022   313      Hydrological         Flood
# 12520  2022-0356-ZAF  2022   356      Hydrological         Flood
# 12521  2022-9784-COD  2022  9784    Climatological       Drought
# 12522  2022-0650-SSD  2022   650      Hydrological         Flood
#
#        Disaster Subtype Disaster Subsubtype Event Name  \
# 0      Tropical cyclone                 NaN      Donna
# 1      Tropical cyclone                 NaN      Donna
# ...
